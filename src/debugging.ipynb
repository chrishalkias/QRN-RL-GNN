# %%
from repeaters import RepeaterNetwork
from agent import AgentGNN
import numpy as np
np.set_printoptions(legacy='1.13')
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
net = RepeaterNetwork(n=4, p_entangle=1, p_swap=1, tau=100)

# %%
# Initialize training variables
N_TRAIN = 4
P_E_TRAIN = 0.8
P_S_TRAIN = 0.8 
TAU_TRAIN = 700

# Intialize tha agent
agent = AgentGNN(n=N_TRAIN, p_entangle=P_E_TRAIN, p_swap=P_S_TRAIN, tau=TAU_TRAIN)
agent.train(episodes = 10_000, plot=True, savefig=False, save_model=False);
# Out:
# 100%|██████████| 10000/10000 [00:07<00:00, 1286.94it/s]
# Total links established = 73

# %%
kappa=0.4
for key, (adj,ent) in net.matrix.items():
    if ent < kappa:
        net.matrix[(key)][1] = 0

# %%
net.matrix
# Out:
# {(0, 1): [1, 0],
#  (1, 2): [1, 0],
#  (0, 3): [0.0, 0],
#  (2, 3): [1, 0],
#  (0, 2): [0.0, 0],
#  (1, 3): [0.0, 0]}

# %%
3.2 != None
# Out:
# True

# %%
TODO
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 TODO
#
# NameError: name 'TODO' is not defined
